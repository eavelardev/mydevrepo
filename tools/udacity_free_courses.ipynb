# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
pd.options.display.max_colwidth = 100

# %%
file_name = r"C:\Users\eduar\mydevrepo\tools\udacity_free_courses.html"
f = open(file_name, "r", encoding="utf-8")
html_doc = f.read()

# %%
soup = BeautifulSoup(html_doc, "html.parser")

# %%
levels = set([level.string for level in soup.find_all('span', class_='card_level__2HNxe')])
levels
# Out:
# {None, 'advanced', 'beginner', 'intermediate'}

# %%
periods = set([str(period.string).split()[-1] for period in soup.find_all('span', class_='card_duration__1hWII')])
periods
# Out:
# {'Day', 'Days', 'Hour', 'Hours', 'Month', 'Months', 'None', 'Week', 'Weeks'}

# %%
affiliates = set([affiliate.string for affiliate in soup.find_all('p', class_='card_affiliatesContent__26Up9')])
all_affiliates = set()

for affiliate in affiliates:
    course_affiliates = [course_affiliate.strip() for course_affiliate in affiliate.split(',')]
    all_affiliates.update(course_affiliates)

# all_affiliates

# %%
cards = soup.find_all('a', class_='card_container__25DrK')

# %%
def get_num_weeks(duration):
    num_period, period = duration.split()
    num_weeks = int(num_period)

    if period.startswith('None'):
        num_weeks = None
    elif period.startswith('Hour'):
        num_weeks = 0
    elif period.startswith('Day'):
        num_weeks = 0
    elif period.startswith('Month'):
        num_weeks *= 4
        
    num_weeks = int(num_weeks)    

    return num_weeks

# %%
data = []

for card in cards:

    course_name = card.find('h2', class_='card_title__35G97').string
    course_summary = card.find('p', class_='card_summary__1HlQ7').string
    course_detailContent = card.find('p', class_='card_detailContent__2eJIl')
    if course_detailContent:
        course_detailContent = course_detailContent.string
    course_url = 'https://www.udacity.com' + card['href']

    affiliates = card.find('p', class_='card_affiliatesContent__26Up9')
    if affiliates:
        affiliates = affiliates.string.rstrip()
    else:
        affiliates = ''

    level = card.find('span', class_='card_level__2HNxe').string

    duration = card.find('span', class_='card_duration__1hWII').string

    num_weeks = None

    if duration:
        num_weeks = get_num_weeks(duration)

    course = {
        'affiliates': affiliates,
        'course_name': course_name,
        'level': level,
        'num_weeks': num_weeks,
        'duration': duration,
        'course_url': course_url,
        'course_summary': course_summary,
        'course_detailContent': course_detailContent
    }

    data.append(course)

# %%
# online_df = pd.DataFrame(data=data).sort_values(by='num_weeks')
online_df = pd.DataFrame(data=data)
len(online_df)
# Out:
# 191

# %%
courses_file = 'udacity_free_courses.csv'

# %%
def read_local_curses():
    return pd.read_csv(courses_file)

# %%
df = read_local_curses()

# %%
# new courses
online_df[~online_df['course_name'].isin(df['course_name'])]
# Out:
# Empty DataFrame
# Columns: [affiliates, course_name, level, num_weeks, duration, course_url, course_summary, course_detailContent]
# Index: []

# %%
# Not listed courses
df[~df['course_name'].isin(online_df['course_name'])]
# Out:
#     affiliates                      course_name  year         level  \
# 191     Kaggle  Intro to Descriptive Statistics   NaN      beginner
# 192      Bosch                 AIoT Foundations   NaN  intermediate
# 193        NaN            Intro to Data Science   NaN  intermediate
#
#      num_weeks  duration completed  \
# 191        8.0  2 Months       NaN
# 192        8.0  2 Months       NaN
# 193        8.0  2 Months       NaN
#
#                                                                 course_url  \
# 191  https://www.udacity.com/course/intro-to-descriptive-statistics--ud827
# 192                 https://www.udacity.com/course/aiot-foundations--ud074
# 193            https://www.udacity.com/course/intro-to-data-science--ud359
#
#                                                                                           course_summary  \
# 191  Statistics is an important field of math that is used to analyze, interpret, and predict outcome...
# 192  Immerse yourself in the full lifecycle of AIoT-enabled products and solutions by exploring AIoT ...
# 193           The Introduction to Data Science class will survey the foundational topics in data science
#
#     course_detailContent
# 191                  NaN
# 192                  NaN
# 193                  NaN

# %%
# year courses
# local_free_courses[local_free_courses['year'].notna()]

# %%
# Update file
# df.insert(6, "completed", ['' for i in range(len(df))], True)
# df

# %%
# Update date
# course_year = 2021
# df.loc[df['course_name'] == course_name_update, 'year'] = course_year

# %%
# Check Course
# course_name_update = "Statistics"
# course_name_update in df['course_name'].to_list()

# %%
# Add Course

# affiliates = None
# year = None
# course_url = 'https://www.udacity.com/course/intro-to-data-science--ud359'
# level = 'intermediate' # [None, 'advanced', 'beginner', 'intermediate']
# duration = '2 Months' # ['Day', 'Days', 'Hour', 'Hours', 'Month', 'Months', 'None', 'Week', 'Weeks']
# num_weeks = get_num_weeks(duration)
# course_summary = 'The Introduction to Data Science class will survey the foundational topics in data science'

# new_course = {
#     'affiliates': [affiliates],
#     'year': [year],
#     'course_name': [course_name_update],
#     'level': [level],
#     'num_weeks': [num_weeks],
#     'duration': [duration],
#     'completed': [None],
#     'course_url': [course_url],
#     'course_summary': [course_summary],
#     'course_detailContent': [None]}

# new_df = pd.concat([df, pd.DataFrame(data=new_course)], ignore_index=True)
# new_df.to_csv(courses_file, index=False)
# df = read_local_curses()

# %%
# Update completed
# df.loc[df['course_name'] == course_name_update, 'completed'] = 'yes'

# %%
mycourses = pd.Series([
    'Introduction to Python Programming',
    'Intro to Deep Learning with PyTorch',
    'Introduction to Machine Learning Course',
    'AWS DeepRacer',
    'AIoT Foundations',
    'Introduction to TensorFlow Lite',
    'Reinforcement Learning',
    'Introduction to Graduate Algorithms',
    'Intro to TensorFlow for Deep Learning',
    'Machine Learning',
    'Intro to Data Science',
    'Data Science Interview Prep',
    'Machine Learning: Unsupervised Learning',
    'AWS Machine Learning Foundations Course'
])
len(mycourses)
# Out:
# 14

# %%
# mycurses not in local
mycourses[~mycourses.isin(df['course_name'])]
# Out:
# Series([], dtype: object)

# %%
def get_course(tag1, tag2=''):
    
    tag1 = tag1.lower()
    tag2 = tag2.lower()

    if tag2 != '':
        new_df = df[
            df['affiliates'].str.lower().str.contains(tag1) | 
            df['affiliates'].str.lower().str.contains(tag2) | 
            df['course_name'].str.lower().str.contains(tag1) | 
            df['course_name'].str.lower().str.contains(tag2) |
            df['course_summary'].str.lower().str.contains(tag1) | 
            df['course_summary'].str.lower().str.contains(tag2) | 
            df['course_detailContent'].str.lower().str.contains(tag1) | 
            df['course_detailContent'].str.lower().str.contains(tag2) 
        ]      
    else:
        new_df = df[
            df['affiliates'].str.lower().str.contains(tag1) | 
            df['course_name'].str.lower().str.contains(tag1) |
            df['course_summary'].str.lower().str.contains(tag1) | 
            df['course_detailContent'].str.lower().str.contains(tag1)]

    return new_df[['affiliates', 'course_name', 'year', 'level', 'num_weeks', 'duration', 'completed', 'course_url']]

# %%
get_course('TensorFlow')
# Out:
#           affiliates                            course_name  year  \
# 159  TensorFlow Lite        Introduction to TensorFlow Lite   NaN
# 160       TensorFlow  Intro to TensorFlow for Deep Learning   NaN
#
#             level  num_weeks  duration completed  \
# 159  intermediate        8.0  2 Months       NaN
# 160  intermediate        8.0  2 Months       NaN
#
#                                                                       course_url
# 159               https://www.udacity.com/course/intro-to-tensorflow-lite--ud190
# 160  https://www.udacity.com/course/intro-to-tensorflow-for-deep-learning--ud187

# %%
get_course('AWS', 'Amazon Web Services')
# Out:
#               affiliates                              course_name    year  \
# 54         AWS DeepRacer                            AWS DeepRacer     NaN
# 74   Amazon Web Services                   Full Stack Foundations     NaN
# 148                  NaN  AWS Machine Learning Foundations Course  2021.0
#
#             level  num_weeks  duration completed  \
# 54   intermediate        2.0   2 Weeks       NaN
# 74   intermediate        3.0   3 Weeks       NaN
# 148  intermediate        8.0  2 Months       NaN
#
#                                                                  course_url
# 54                      https://www.udacity.com/course/aws-deepracer--ud014
# 74             https://www.udacity.com/course/full-stack-foundations--ud088
# 148  https://www.udacity.com/course/aws-machine-learning-foundations--ud065

# %%
get_course('Facebook')
# Out:
#                   affiliates                               course_name  year  \
# 26   Facebook for Developers  Passwordless Login Solutions for Android   NaN
# 29   Facebook for Developers      Passwordless Login Solutions for iOS   NaN
# 57   Facebook for Developers       Mobile Design and Usability for iOS   NaN
# 61   Facebook for Developers   Mobile Design and Usability for Android   NaN
# 141              Facebook AI                     Secure and Private AI   NaN
# 153                 Facebook                      Data Analysis with R   NaN
# 157              Facebook AI       Intro to Deep Learning with PyTorch   NaN
#
#             level  num_weeks  duration completed  \
# 26            NaN        1.0    1 Week       NaN
# 29   intermediate        1.0    1 Week       NaN
# 57   intermediate        2.0   2 Weeks       NaN
# 61   intermediate        2.0   2 Weeks       NaN
# 141      advanced        8.0  2 Months       NaN
# 153  intermediate        8.0  2 Months       NaN
# 157  intermediate        8.0  2 Months       NaN
#
#                                                                          course_url
# 26   https://www.udacity.com/course/passwordless-login-solutions-for-android--ud357
# 29      https://www.udacity.com/course/passwordless-login-solutions-for-ios--ud1028
# 57       https://www.udacity.com/course/mobile-design-and-usability-for-ios--ud1034
# 61    https://www.udacity.com/course/mobile-design-and-usability-for-android--ud358
# 141                     https://www.udacity.com/course/secure-and-private-ai--ud185
# 153                      https://www.udacity.com/course/data-analysis-with-r--ud651
# 157                     https://www.udacity.com/course/deep-learning-pytorch--ud188

# %%
get_course('machine learning')
# Out:
#                           affiliates  \
# 14                           Insight
# 21                               NaN
# 23                               NaN
# 54                     AWS DeepRacer
# 90   Georgia Institute of Technology
# 93                   Microsoft Azure
# 145                  Microsoft Azure
# 148                              NaN
# 162                              NaN
# 169  Georgia Institute of Technology
# 170  Georgia Institute of Technology
# 173  Georgia Institute of Technology
# 175                              NaN
# 180  Georgia Institute of Technology
# 183  Georgia Institute of Technology
# 191                           Kaggle
#
#                                                 course_name    year  \
# 14                                                    Spark     NaN
# 21                   Machine Learning Interview Preparation     NaN
# 23                              Data Science Interview Prep  2015.0
# 54                                            AWS DeepRacer     NaN
# 90                  Machine Learning: Unsupervised Learning     NaN
# 93                                          AI Fundamentals     NaN
# 145  Introduction to Machine Learning using Microsoft Azure     NaN
# 148                 AWS Machine Learning Foundations Course  2021.0
# 162                 Introduction to Machine Learning Course     NaN
# 169                                 Artificial Intelligence     NaN
# 170                         Introduction to Computer Vision     NaN
# 173                                  Reinforcement Learning     NaN
# 175                        Intro to Artificial Intelligence     NaN
# 180                            Machine Learning for Trading     NaN
# 183                                        Machine Learning     NaN
# 191                         Intro to Descriptive Statistics     NaN
#
#             level  num_weeks  duration completed  \
# 14   intermediate        0.0  10 Hours       NaN
# 21   intermediate        1.0    1 Week       NaN
# 23   intermediate        1.0    1 Week       yes
# 54   intermediate        2.0   2 Weeks       NaN
# 90   intermediate        4.0   1 Month       NaN
# 93       beginner        4.0   1 Month       NaN
# 145  intermediate        8.0  2 Months       NaN
# 148  intermediate        8.0  2 Months       NaN
# 162  intermediate       10.0  10 Weeks       NaN
# 169  intermediate       16.0  4 Months       NaN
# 170  intermediate       16.0  4 Months       NaN
# 173      advanced       16.0  4 Months       NaN
# 175  intermediate       16.0  4 Months       NaN
# 180  intermediate       16.0  4 Months       NaN
# 183  intermediate       16.0  4 Months       NaN
# 191      beginner        8.0  2 Months       NaN
#
#                                                                                          course_url
# 14                                    https://www.udacity.com/course/learn-spark-at-udacity--ud2002
# 21                           https://www.udacity.com/course/machine-learning-interview-prep--ud1001
# 23                                https://www.udacity.com/course/data-science-interview-prep--ud944
# 54                                              https://www.udacity.com/course/aws-deepracer--ud014
# 90                     https://www.udacity.com/course/machine-learning-unsupervised-learning--ud741
# 93                                            https://www.udacity.com/course/ai-fundamentals--ud099
# 145  https://www.udacity.com/course/introduction-to-machine-learning-using-microsoft-azure--ud00333
# 148                          https://www.udacity.com/course/aws-machine-learning-foundations--ud065
# 162                                 https://www.udacity.com/course/intro-to-machine-learning--ud120
# 169                                   https://www.udacity.com/course/artificial-intelligence--ud954
# 170                           https://www.udacity.com/course/introduction-to-computer-vision--ud810
# 173                                    https://www.udacity.com/course/reinforcement-learning--ud600
# 175                          https://www.udacity.com/course/intro-to-artificial-intelligence--cs271
# 180                              https://www.udacity.com/course/machine-learning-for-trading--ud501
# 183                                          https://www.udacity.com/course/machine-learning--ud262
# 191                           https://www.udacity.com/course/intro-to-descriptive-statistics--ud827

# %%
get_course('deep learning')
# Out:
#           affiliates                                 course_name  year  \
# 95               NaN  Intel® Edge AI Fundamentals with OpenVINO™   NaN
# 157      Facebook AI         Intro to Deep Learning with PyTorch   NaN
# 159  TensorFlow Lite             Introduction to TensorFlow Lite   NaN
# 160       TensorFlow       Intro to TensorFlow for Deep Learning   NaN
#
#             level  num_weeks  duration completed  \
# 95   intermediate        4.0   1 Month       NaN
# 157  intermediate        8.0  2 Months       NaN
# 159  intermediate        8.0  2 Months       NaN
# 160  intermediate        8.0  2 Months       NaN
#
#                                                                          course_url
# 95   https://www.udacity.com/course/intel-edge-AI-fundamentals-with-openvino--ud132
# 157                     https://www.udacity.com/course/deep-learning-pytorch--ud188
# 159                  https://www.udacity.com/course/intro-to-tensorflow-lite--ud190
# 160     https://www.udacity.com/course/intro-to-tensorflow-for-deep-learning--ud187

# %%
get_course('data scien')
# Out:
#                           affiliates                      course_name    year  \
# 23                               NaN      Data Science Interview Prep  2015.0
# 151                          MongoDB      Data Wrangling with MongoDB     NaN
# 183  Georgia Institute of Technology                 Machine Learning     NaN
# 191                           Kaggle  Intro to Descriptive Statistics     NaN
# 193                              NaN            Intro to Data Science     NaN
#
#             level  num_weeks  duration completed  \
# 23   intermediate        1.0    1 Week       yes
# 151  intermediate        8.0  2 Months       NaN
# 183  intermediate       16.0  4 Months       NaN
# 191      beginner        8.0  2 Months       NaN
# 193  intermediate        8.0  2 Months       NaN
#
#                                                                 course_url
# 23       https://www.udacity.com/course/data-science-interview-prep--ud944
# 151      https://www.udacity.com/course/data-wrangling-with-mongodb--ud032
# 183                 https://www.udacity.com/course/machine-learning--ud262
# 191  https://www.udacity.com/course/intro-to-descriptive-statistics--ud827
# 193            https://www.udacity.com/course/intro-to-data-science--ud359

# %%
get_course('python')
# Out:
#               affiliates                            course_name    year  \
# 28                   NaN                     HTTP & Web Servers     NaN
# 65                   NaN  Authentication & Authorization: OAuth     NaN
# 70                   NaN                 Designing RESTful APIs     NaN
# 74   Amazon Web Services                 Full Stack Foundations     NaN
# 96                   NaN          Intro to Relational Databases     NaN
# 120                  NaN     Introduction to Python Programming  2018.0
# 121                  NaN                 Intro to Data Analysis     NaN
# 139                  NaN       Differential Equations in Action     NaN
# 149                  NaN            Design of Computer Programs     NaN
# 155                  NaN                     Software Debugging     NaN
# 168                  NaN        Linear Algebra Refresher Course     NaN
#
#             level  num_weeks  duration completed  \
# 28   intermediate        1.0    1 Week       NaN
# 65   intermediate        2.0   2 Weeks       NaN
# 70   intermediate        3.0   3 Weeks       NaN
# 74   intermediate        3.0   3 Weeks       NaN
# 96   intermediate        4.0   4 Weeks       NaN
# 120      beginner        5.0   5 Weeks       yes
# 121      beginner        6.0   6 Weeks       NaN
# 139  intermediate        8.0  2 Months       NaN
# 149      advanced        8.0  2 Months       NaN
# 155  intermediate        8.0  2 Months       NaN
# 168  intermediate       16.0  4 Months       NaN
#
#                                                                    course_url
# 28                     https://www.udacity.com/course/http-web-servers--ud303
# 65   https://www.udacity.com/course/authentication-authorization-oauth--ud330
# 70               https://www.udacity.com/course/designing-restful-apis--ud388
# 74               https://www.udacity.com/course/full-stack-foundations--ud088
# 96        https://www.udacity.com/course/intro-to-relational-databases--ud197
# 120             https://www.udacity.com/course/introduction-to-python--ud1110
# 121              https://www.udacity.com/course/intro-to-data-analysis--ud170
# 139    https://www.udacity.com/course/differential-equations-in-action--cs222
# 149         https://www.udacity.com/course/design-of-computer-programs--cs212
# 155                  https://www.udacity.com/course/software-debugging--cs259
# 168     https://www.udacity.com/course/linear-algebra-refresher-course--ud953
